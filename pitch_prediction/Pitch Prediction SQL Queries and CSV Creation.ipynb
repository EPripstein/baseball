# %% [markdown]
# ## Pitch Prediction SQL Queries and CSV Creation
#
# The goal of this project is to see if I can build a model to predict what pitch a pitcher is going to throw next. As a start, I used the pitchRx package in R to create a SQLite database with all of the PITCHF/x data needed. Here I'm going to take a look at the tables in the database, write a query to get the data I need, and save it to a CSV for future use.

# %%
#Import necessary modules

import pandas as pd
import numpy as np
import sqlite3

# %%
#Create connection to sqlite database

db_path = "2017_pitchfx.sqlite3"
con = sqlite3.connect(db_path)

# %%
#View tables in the database

cur = con.cursor()
cur.execute("SELECT name FROM sqlite_master WHERE type='table';")
tables = cur.fetchall()
print(tables)
# Out:
# [('atbat',), ('action',), ('pitch',), ('po',), ('runner',)]

# %%
#Print columns in tables

def print_col_names(table_list):
    for table in table_list:
        cur.execute("SELECT * FROM %s;" %table)
        names = list(map(lambda x: x[0], cur.description))
        print('Columns in %s: \n' %table, names, '\n')
        
print_col_names(tables)
# Out:
# Columns in atbat:
#  ['pitcher', 'batter', 'num', 'b', 's', 'o', 'start_tfs', 'start_tfs_zulu', 'stand', 'b_height', 'p_throws', 'atbat_des', 'atbat_des_es', 'event', 'score', 'home_team_runs', 'away_team_runs', 'url', 'inning_side', 'inning', 'next_', 'event2', 'event3', 'batter_name', 'pitcher_name', 'event4', 'gameday_link', 'date', 'event_num', 'event_es', 'play_guid', 'event2_es', 'end_tfs_zulu', 'event3_es']
#
# Columns in action:
#  ['b', 's', 'o', 'des', 'des_es', 'event', 'tfs', 'tfs_zulu', 'player', 'pitch', 'url', 'inning_side', 'inning', 'next_', 'num', 'score', 'home_team_runs', 'away_team_runs', 'event2', 'gameday_link', 'event_es', 'event_num', 'play_guid', 'event2_es']
#
# Columns in pitch:
#  ['des', 'des_es', 'id', 'type', 'tfs', 'tfs_zulu', 'x', 'y', 'sv_id', 'start_speed', 'end_speed', 'sz_top', 'sz_bot', 'pfx_x', 'pfx_z', 'px', 'pz', 'x0', 'y0', 'z0', 'vx0', 'vy0', 'vz0', 'ax', 'ay', 'az', 'break_y', 'break_angle', 'break_length', 'pitch_type', 'type_confidence', 'zone', 'nasty', 'spin_dir', 'spin_rate', 'cc', 'mt', 'url', 'inning_side', 'inning', 'next_', 'num', 'on_1b', 'on_2b', 'on_3b', 'count', 'gameday_link', 'code', 'event_num', 'play_guid']
#
# Columns in po:
#  ['des', 'url', 'inning_side', 'inning', 'next_', 'num', 'gameday_link', 'des_es', 'event_num', 'play_guid', 'catcher']
#
# Columns in runner:
#  ['id', 'start', 'end', 'event', 'score', 'rbi', 'earned', 'url', 'inning_side', 'inning', 'next_', 'num', 'gameday_link', 'event_num']

# %% [markdown]
# ## Data Required
#
# Here is the list of columns I'm interested in for building my model:
#
# From the atbat table:
#
# |Column|Description|
# |:-----|:-----------|
# |num|Number of the at bat in the game|
# |b|Balls|
# |s|Strikes|
# |o|Outs|
# |stand|Batter handedness|
# |p_throws|Pitcher handedness|
# |batter_name|Batter name|
# |pitcher_name|Pitcher name|
# |inning_side|Top or bottom of inning|
#
#
# From the pitch table:
#
# |Column|Description|
# |:-----|:-----------|
# |px|the left/right distance, in feet, of the pitch from the middle of the plate as it crossed home plate. The PITCHf/x coordinate system is oriented to the catcher’s/umpire’s perspective, with distances to the right being positive and to the left being negative. ([source](https://fastballs.wordpress.com/2007/08/02/glossary-of-the-gameday-pitch-fields/))|
# |pz|the height of the pitch in feet as it crossed the front of home plate. ([source](https://fastballs.wordpress.com/2007/08/02/glossary-of-the-gameday-pitch-fields/))|
# |pitch_type|MLBAM's prediction for the type of pitch thrown|
# |type_confidence|Level of confidence in the pitch type prediction|
# |on_1b|ID of the runner on first base|
# |on_2b|ID of the runner on second base|
# |on_3b|ID of the runner on third base|
# |count|The current count in the at bat|
#
#
# Before I perform the query, I'll take a look at the tables to make sure the data looks as I expect, and to figure out what fields to join on.

# %%
#Look at the top 5 columns of the 'atbat' table. 

atbat = pd.read_sql_query("SELECT * from atbat LIMIT 20", con)
atbat
# Out:
#      pitcher    batter   num    b    s    o start_tfs        start_tfs_zulu  \
# 0   488984.0  434670.0  45.0  2.0  1.0  3.0    215458  2017-04-15T21:54:58Z
# 1   488984.0  453064.0  57.0  2.0  3.0  3.0    012834  2017-04-07T01:28:34Z
# 2   488984.0  434778.0  56.0  0.0  3.0  2.0    012712  2017-04-07T01:27:12Z
# 3   488984.0  430832.0  67.0  1.0  2.0  2.0    200509  2017-04-09T20:05:09Z
# 4   488984.0  407812.0  56.0  3.0  2.0  3.0    012739  2017-04-14T01:27:39Z
# 5   488984.0  519048.0  49.0  1.0  2.0  0.0    220642  2017-04-15T22:06:42Z
# 6   488984.0  455759.0  51.0  0.0  0.0  0.0    170758  2017-04-17T17:07:58Z
# 7   488984.0  605141.0  44.0  1.0  2.0  2.0    215313  2017-04-15T21:53:13Z
# 8   488984.0  593523.0  53.0  0.0  3.0  3.0    171110  2017-04-17T17:11:10Z
# 9   488984.0  430832.0  55.0  3.0  2.0  1.0    012413  2017-04-07T01:24:13Z
# 10  488984.0  593428.0  50.0  0.0  1.0  0.0    220909  2017-04-15T22:09:09Z
# 11  488984.0  458731.0  69.0  4.0  0.0  1.0    020210  2017-04-05T02:02:10Z
# 12  488984.0  591720.0  68.0  1.0  1.0  1.0    020104  2017-04-05T02:01:04Z
# 13  488984.0  581527.0  65.0  0.0  1.0  1.0    200333  2017-04-09T20:03:33Z
# 14  488984.0  506702.0  52.0  2.0  0.0  2.0    170908  2017-04-17T17:09:08Z
# 15  488984.0  572365.0  66.0  0.0  0.0  2.0    200429  2017-04-09T20:04:29Z
# 16  488984.0  455759.0  52.0  4.0  2.0  1.0    221454  2017-04-15T22:14:54Z
# 17  488984.0  596142.0  70.0  1.0  2.0  2.0    020338  2017-04-05T02:03:38Z
# 18  488984.0  467055.0  51.0  2.0  2.0  1.0    221044  2017-04-15T22:10:44Z
# 19  488984.0  434778.0  68.0  1.0  1.0  3.0    200732  2017-04-09T20:07:32Z
#
#    stand b_height    ...      pitcher_name event4  \
# 0      R      6-2    ...      Tommy Hunter   None
# 1      R      6-3    ...      Tommy Hunter   None
# 2      L      6-1    ...      Tommy Hunter   None
# 3      R      6-0    ...      Tommy Hunter   None
# 4      R      6-4    ...      Tommy Hunter   None
# 5      L      6-2    ...      Tommy Hunter   None
# 6      R      6-2    ...      Tommy Hunter   None
# 7      R      5-9    ...      Tommy Hunter   None
# 8      L      6-0    ...      Tommy Hunter   None
# 9      R      6-0    ...      Tommy Hunter   None
# 10     R      6-1    ...      Tommy Hunter   None
# 11     L     5-11    ...      Tommy Hunter   None
# 12     R      5-8    ...      Tommy Hunter   None
# 13     R      5-9    ...      Tommy Hunter   None
# 14     L     5-10    ...      Tommy Hunter   None
# 15     L     5-10    ...      Tommy Hunter   None
# 16     R      6-2    ...      Tommy Hunter   None
# 17     R      6-2    ...      Tommy Hunter   None
# 18     L     5-11    ...      Tommy Hunter   None
# 19     L      6-1    ...      Tommy Hunter   None
#
#                       gameday_link        date event_num         event_es  \
# 0   gid_2017_04_15_tbamlb_bosmlb_1  2017_04_15       351  Roletazo de Out
# 1   gid_2017_04_06_tormlb_tbamlb_1  2017_04_06       443           Ponche
# 2   gid_2017_04_06_tormlb_tbamlb_1  2017_04_06       435           Ponche
# 3   gid_2017_04_09_tormlb_tbamlb_1  2017_04_09       574            Doble
# 4   gid_2017_04_13_tbamlb_nyamlb_1  2017_04_13       447  Roletazo de Out
# 5   gid_2017_04_15_tbamlb_bosmlb_1  2017_04_15       385         Sencillo
# 6   gid_2017_04_17_tbamlb_bosmlb_1  2017_04_17       414         Sencillo
# 7   gid_2017_04_15_tbamlb_bosmlb_1  2017_04_15       344  Roletazo de Out
# 8   gid_2017_04_17_tbamlb_bosmlb_1  2017_04_17       430           Ponche
# 9   gid_2017_04_06_tormlb_tbamlb_1  2017_04_06       429  Roletazo de Out
# 10  gid_2017_04_15_tbamlb_bosmlb_1  2017_04_15       391         Sencillo
# 11  gid_2017_04_04_nyamlb_tbamlb_1  2017_04_04       572   Base por Bolas
# 12  gid_2017_04_04_nyamlb_tbamlb_1  2017_04_04       565  Roletazo de Out
# 13  gid_2017_04_09_tormlb_tbamlb_1  2017_04_09       562  Roletazo de Out
# 14  gid_2017_04_17_tbamlb_bosmlb_1  2017_04_17       424   Elevado de Out
# 15  gid_2017_04_09_tormlb_tbamlb_1  2017_04_09       566  Roletazo de Out
# 16  gid_2017_04_15_tbamlb_bosmlb_1  2017_04_15       413   Base por Bolas
# 17  gid_2017_04_04_nyamlb_tbamlb_1  2017_04_04       579    LÃ­nea de Out
# 18  gid_2017_04_15_tbamlb_bosmlb_1  2017_04_15       403      Out Forzado
# 19  gid_2017_04_09_tormlb_tbamlb_1  2017_04_09       580    LÃ­nea de Out
#
#                                play_guid event2_es          end_tfs_zulu  \
# 0   c66c23f8-2210-4304-84c5-a13399ed0e46      None                  None
# 1   4c0d14ab-65f5-454b-9244-e00f2b67bddd      None  2017-04-07T01:30:17Z
# 2   6322bca5-10d2-4860-9dd7-ac9e6be5ed8f      None  2017-04-07T01:28:33Z
# 3   001f10f5-1c5e-48c8-b484-c9f14a7767c5      None                  None
# 4   ef27f153-6121-41c2-b0e6-612a0971fdef      None                  None
# 5   617267e2-547a-40f2-92e9-054dc36f04c5      None                  None
# 6   b8cfe791-1cf7-425d-a54c-858b05b401ef      None                  None
# 7   29c385e7-a2df-4d34-8f15-46ecaadde910      None                  None
# 8   3a5a2812-fac7-430c-92b7-80dd9807375d      None                  None
# 9   299a3caf-3947-45bc-9570-4aa35a309e6f      None  2017-04-07T01:26:53Z
# 10  83236fe8-bb9d-4b16-906b-49bb4d4fba8b      None                  None
# 11  d8ca6283-425d-4c7e-853e-b45dafa558a4      None                  None
# 12  cd34dcc5-8985-4671-88ed-d9b734e6ed11      None                  None
# 13  d4992ee8-632e-4650-86bd-17990d028a54      None                  None
# 14  386eaa15-57e4-4941-93fa-13824212b1f6      None                  None
# 15  51291002-bcc4-4443-9256-c494fd774f1c      None                  None
# 16  23f5e7e1-2fc5-4a34-adbd-b9d4befefbdf      None                  None
# 17  bf49bcb7-0ef0-449d-9d86-49a256f23a47      None                  None
# 18  3217bffe-8a17-4993-aa68-d4998051608b      None                  None
# 19  10f6f80d-64c1-438d-bd9f-1c419c8d3715      None                  None
#
#     event3_es
# 0        None
# 1        None
# 2        None
# 3        None
# 4        None
# 5        None
# 6        None
# 7        None
# 8        None
# 9        None
# 10       None
# 11       None
# 12       None
# 13       None
# 14       None
# 15       None
# 16       None
# 17       None
# 18       None
# 19       None
#
# [20 rows x 34 columns]

# %%
#Next let's take a look at the 'pitch' table

pitch = pd.read_sql_query("SELECT * from pitch", con)
pitch
# Out:
#                               des                        des_es     id type  \
# 0                            Ball                     Bola mala    3.0    B
# 1                   Called Strike                Strike cantado    4.0    S
# 2                            Ball                     Bola mala    5.0    B
# 3                   Called Strike                Strike cantado    6.0    S
# 4                            Foul                          Foul    7.0    S
# 5                 In play, out(s)              En juego, out(s)    8.0    X
# 6                 In play, out(s)              En juego, out(s)   12.0    X
# 7                   Called Strike                Strike cantado   17.0    S
# 8                            Ball                     Bola mala   18.0    B
# 9                            Ball                     Bola mala   19.0    B
# 10                           Ball                     Bola mala   20.0    B
# 11                           Ball                     Bola mala   21.0    B
# 12                           Ball                     Bola mala   25.0    B
# 13                  Called Strike                Strike cantado   26.0    S
# 14                           Ball                     Bola mala   27.0    B
# 15                           Ball                     Bola mala   28.0    B
# 16                In play, out(s)              En juego, out(s)   29.0    X
# 17                  Called Strike                Strike cantado   36.0    S
# 18                In play, no out              En juego, no out   37.0    X
# 19                           Ball                     Bola mala   41.0    B
# 20                           Ball                     Bola mala   42.0    B
# 21                           Foul                          Foul   43.0    S
# 22                In play, no out              En juego, no out   44.0    X
# 23                Swinging Strike              Strike tirándole   49.0    S
# 24                In play, run(s)          En juego, carrera(s)   50.0    X
# 25                   Ball In Dirt             Bola por el suelo   56.0    B
# 26                           Ball                     Bola mala   57.0    B
# 27                In play, no out              En juego, no out   58.0    X
# 28                   Ball In Dirt             Bola por el suelo   63.0    B
# 29                   Ball In Dirt             Bola por el suelo   64.0    B
# ...                           ...                           ...    ...  ...
# 725024              Called Strike                Strike cantado  492.0    S
# 725025                       Foul                          Foul  493.0    S
# 725026                       Ball                     Bola mala  494.0    B
# 725027                       Foul                          Foul  495.0    S
# 725028                       Foul                          Foul  496.0    S
# 725029                       Foul                          Foul  497.0    S
# 725030                   Foul Tip                    Foul atrás  498.0    S
# 725031                       Ball                     Bola mala  502.0    B
# 725032              Called Strike                Strike cantado  503.0    S
# 725033                       Foul                          Foul  504.0    S
# 725034  Swinging Strike (Blocked)  Strike tirándole (Bloqueado)  505.0    S
# 725035            In play, out(s)              En juego, out(s)  512.0    X
# 725036              Called Strike                Strike cantado  516.0    S
# 725037                       Foul                          Foul  517.0    S
# 725038                       Ball                     Bola mala  518.0    B
# 725039                       Foul                          Foul  519.0    S
# 725040  Swinging Strike (Blocked)  Strike tirándole (Bloqueado)  520.0    S
# 725041              Called Strike                Strike cantado  526.0    S
# 725042                       Ball                     Bola mala  527.0    B
# 725043            In play, no out              En juego, no out  528.0    X
# 725044                       Ball                     Bola mala  532.0    B
# 725045                       Ball                     Bola mala  533.0    B
# 725046                       Ball                     Bola mala  534.0    B
# 725047                       Ball                     Bola mala  535.0    B
# 725048              Called Strike                Strike cantado  540.0    S
# 725049            In play, out(s)              En juego, out(s)  550.0    X
# 725050                       Ball                     Bola mala  554.0    B
# 725051            In play, run(s)          En juego, carrera(s)  555.0    X
# 725052            In play, out(s)              En juego, out(s)  560.0    X
# 725053            In play, out(s)              En juego, out(s)  564.0    X
#
#            tfs              tfs_zulu       x       y          sv_id  \
# 0       171214  2017-04-02T17:12:14Z   78.78  203.77  170402_171214
# 1       171239  2017-04-02T17:12:39Z  111.67  159.76  170402_171240
# 2       171303  2017-04-02T17:13:03Z  153.12  160.97  170402_171303
# 3       171323  2017-04-02T17:13:23Z  148.28  162.52  170402_171323
# 4       171356  2017-04-02T17:13:56Z   87.08  194.67  170402_171356
# 5       171429  2017-04-02T17:14:29Z  114.01  188.29  170402_171430
# 6       171520  2017-04-02T17:15:20Z  113.85  188.22  170402_171520
# 7       171632  2017-04-02T17:16:32Z  138.26  187.76  170402_171632
# 8       171649  2017-04-02T17:16:49Z  119.20    0.00  170402_171649
# 9       171710  2017-04-02T17:17:10Z   69.52  222.19  170402_171711
# 10      171735  2017-04-02T17:17:35Z  153.13  129.46  170402_171736
# 11      171754  2017-04-02T17:17:54Z  146.34  131.95  170402_171755
# 12      171835  2017-04-02T17:18:35Z   86.27  151.65  170402_171835
# 13      171856  2017-04-02T17:18:56Z  106.29  195.29  170402_171857
# 14      171923  2017-04-02T17:19:23Z  132.71  140.93  170402_171923
# 15      171946  2017-04-02T17:19:46Z   70.23  185.10  170402_171946
# 16      172013  2017-04-02T17:20:13Z   96.30  191.74  170402_172013
# 17      172432  2017-04-02T17:24:32Z  125.24  197.27  170402_172432
# 18      172451  2017-04-02T17:24:51Z  121.88  204.11  170402_172452
# 19      172536  2017-04-02T17:25:36Z  105.36  201.22  170402_172536
# 20      172557  2017-04-02T17:25:57Z   76.71  213.48  170402_172558
# 21      172628  2017-04-02T17:26:28Z  156.29  179.64  170402_172628
# 22      172657  2017-04-02T17:26:57Z  122.62  189.59  170402_172658
# 23      172849  2017-04-02T17:28:49Z   64.47  217.53  170402_172849
# 24      172941  2017-04-02T17:29:41Z   93.69  181.71  170402_172942
# 25      173043  2017-04-02T17:30:43Z   89.00  244.05  170402_173044
# 26      173115  2017-04-02T17:31:15Z  118.33  217.59  170402_173116
# 27      173138  2017-04-02T17:31:38Z  117.41  205.14  170402_173139
# 28      173242  2017-04-02T17:32:42Z   41.85  238.04  170402_173243
# 29      173311  2017-04-02T17:33:11Z   18.21  226.24  170402_173312
# ...        ...                   ...     ...     ...            ...
# 725024  213156  2017-10-01T21:31:56Z  146.81  159.92  171001_213200
# 725025  213211  2017-10-01T21:32:11Z  123.25  171.44  171001_213217
# 725026  213246  2017-10-01T21:32:46Z  103.00  122.96  171001_213251
# 725027  213303  2017-10-01T21:33:03Z  105.01  173.26  171001_213309
# 725028  213328  2017-10-01T21:33:28Z  115.47  197.89  171001_213334
# 725029  213349  2017-10-01T21:33:49Z  130.68  155.45  171001_213359
# 725030  213414  2017-10-01T21:34:14Z  102.94  154.68  171001_213419
# 725031  213446  2017-10-01T21:34:46Z  143.83  199.54  171001_213451
# 725032  213504  2017-10-01T21:35:04Z  129.23  170.74  171001_213508
# 725033  213519  2017-10-01T21:35:19Z   89.92  164.09  171001_213527
# 725034  213547  2017-10-01T21:35:47Z   81.10  233.26  171001_213552
# 725035  213901  2017-10-01T21:39:01Z  127.88  174.01  171001_213916
# 725036  213937  2017-10-01T21:39:37Z  137.64  179.00  171001_213942
# 725037  213951  2017-10-01T21:39:51Z  125.35  150.19  171001_213956
# 725038  214015  2017-10-01T21:40:15Z  134.57  137.83  171001_214020
# 725039  214032  2017-10-01T21:40:32Z   91.04  163.03  171001_214038
# 725040  214054  2017-10-01T21:40:54Z   63.82  232.45  171001_214104
# 725041  214144  2017-10-01T21:41:44Z  141.73  160.68  171001_214149
# 725042  214201  2017-10-01T21:42:01Z  166.17  189.45  171001_214206
# 725043  214216  2017-10-01T21:42:16Z  103.12  172.86  171001_214231
# 725044  214250  2017-10-01T21:42:50Z  144.53  196.49  171001_214255
# 725045  214307  2017-10-01T21:43:07Z  166.35  138.53  171001_214312
# 725046  214329  2017-10-01T21:43:29Z  141.67  202.07  171001_214334
# 725047  214346  2017-10-01T21:43:46Z  164.45  189.50  171001_214351
# 725048  214420  2017-10-01T21:44:20Z  109.44  150.69  171001_214427
# 725049  214945  2017-10-01T21:49:45Z   98.36  163.69  171001_214954
# 725050  215017  2017-10-01T21:50:17Z  161.59  159.51  171001_215022
# 725051  215029  2017-10-01T21:50:29Z  130.76  165.93  171001_215044
# 725052  215117  2017-10-01T21:51:17Z  131.69  186.86  171001_215124
# 725053  215150  2017-10-01T21:51:50Z  144.42  163.65  171001_215158
#
#         start_speed                  ...                   next_   num  \
# 0              92.1                  ...                       Y   1.0
# 1              92.4                  ...                       Y   1.0
# 2              93.6                  ...                       Y   1.0
# 3              93.2                  ...                       Y   1.0
# 4              88.0                  ...                       Y   1.0
# 5              87.9                  ...                       Y   1.0
# 6              94.7                  ...                       Y   2.0
# 7              94.9                  ...                       Y   3.0
# 8              89.2                  ...                       Y   3.0
# 9              87.3                  ...                       Y   3.0
# 10             95.0                  ...                       Y   3.0
# 11             94.9                  ...                       Y   3.0
# 12             94.5                  ...                       Y   4.0
# 13             87.3                  ...                       Y   4.0
# 14             95.5                  ...                       Y   4.0
# 15             94.2                  ...                       Y   4.0
# 16             87.8                  ...                       Y   4.0
# 17             90.9                  ...                       Y   5.0
# 18             86.6                  ...                       Y   5.0
# 19             90.3                  ...                       Y   6.0
# 20             82.2                  ...                       Y   6.0
# 21             90.1                  ...                       Y   6.0
# 22             90.7                  ...                       Y   6.0
# 23             85.8                  ...                       Y   7.0
# 24             85.7                  ...                       Y   7.0
# 25             87.3                  ...                       Y   8.0
# 26             90.9                  ...                       Y   8.0
# 27             87.6                  ...                       Y   8.0
# 28             85.5                  ...                       Y   9.0
# 29             91.2                  ...                       Y   9.0
# ...             ...                  ...                     ...   ...
# 725024         94.9                  ...                       Y  59.0
# 725025         88.2                  ...                       Y  59.0
# 725026         94.7                  ...                       Y  59.0
# 725027         86.8                  ...                       Y  59.0
# 725028         87.2                  ...                       Y  59.0
# 725029         94.3                  ...                       Y  59.0
# 725030         93.1                  ...                       Y  59.0
# 725031         87.3                  ...                       Y  60.0
# 725032         88.3                  ...                       Y  60.0
# 725033         93.8                  ...                       Y  60.0
# 725034         88.8                  ...                       Y  60.0
# 725035         94.9                  ...                       N  61.0
# 725036         96.6                  ...                       N  62.0
# 725037         96.6                  ...                       N  62.0
# 725038         79.8                  ...                       N  62.0
# 725039         87.4                  ...                       N  62.0
# 725040         87.6                  ...                       N  62.0
# 725041         79.9                  ...                       N  63.0
# 725042         87.6                  ...                       N  63.0
# 725043         96.1                  ...                       N  63.0
# 725044         96.3                  ...                       N  64.0
# 725045         95.6                  ...                       N  64.0
# 725046         88.1                  ...                       N  64.0
# 725047         96.2                  ...                       N  64.0
# 725048         87.8                  ...                       N  65.0
# 725049         95.5                  ...                       N  66.0
# 725050         85.9                  ...                       N  67.0
# 725051         96.4                  ...                       N  67.0
# 725052         96.3                  ...                       N  68.0
# 725053         86.5                  ...                       N  69.0
#
#            on_1b     on_2b     on_3b  count                    gameday_link  \
# 0            NaN       NaN       NaN    0-0  gid_2017_04_02_nyamlb_tbamlb_1
# 1            NaN       NaN       NaN    1-0  gid_2017_04_02_nyamlb_tbamlb_1
# 2            NaN       NaN       NaN    1-1  gid_2017_04_02_nyamlb_tbamlb_1
# 3            NaN       NaN       NaN    2-1  gid_2017_04_02_nyamlb_tbamlb_1
# 4            NaN       NaN       NaN    2-2  gid_2017_04_02_nyamlb_tbamlb_1
# 5            NaN       NaN       NaN    2-2  gid_2017_04_02_nyamlb_tbamlb_1
# 6            NaN       NaN       NaN    0-0  gid_2017_04_02_nyamlb_tbamlb_1
# 7            NaN       NaN       NaN    0-0  gid_2017_04_02_nyamlb_tbamlb_1
# 8            NaN       NaN       NaN    0-1  gid_2017_04_02_nyamlb_tbamlb_1
# 9            NaN       NaN       NaN    1-1  gid_2017_04_02_nyamlb_tbamlb_1
# 10           NaN       NaN       NaN    2-1  gid_2017_04_02_nyamlb_tbamlb_1
# 11           NaN       NaN       NaN    3-1  gid_2017_04_02_nyamlb_tbamlb_1
# 12      595885.0       NaN       NaN    0-0  gid_2017_04_02_nyamlb_tbamlb_1
# 13      595885.0       NaN       NaN    1-0  gid_2017_04_02_nyamlb_tbamlb_1
# 14      595885.0       NaN       NaN    1-1  gid_2017_04_02_nyamlb_tbamlb_1
# 15      595885.0       NaN       NaN    2-1  gid_2017_04_02_nyamlb_tbamlb_1
# 16      595885.0       NaN       NaN    3-1  gid_2017_04_02_nyamlb_tbamlb_1
# 17           NaN       NaN       NaN    0-0  gid_2017_04_02_nyamlb_tbamlb_1
# 18           NaN       NaN       NaN    0-1  gid_2017_04_02_nyamlb_tbamlb_1
# 19      572816.0       NaN       NaN    0-0  gid_2017_04_02_nyamlb_tbamlb_1
# 20      572816.0       NaN       NaN    1-0  gid_2017_04_02_nyamlb_tbamlb_1
# 21      572816.0       NaN       NaN    2-0  gid_2017_04_02_nyamlb_tbamlb_1
# 22      572816.0       NaN       NaN    2-1  gid_2017_04_02_nyamlb_tbamlb_1
# 23           NaN  595281.0  572816.0    0-0  gid_2017_04_02_nyamlb_tbamlb_1
# 24           NaN  595281.0  572816.0    0-1  gid_2017_04_02_nyamlb_tbamlb_1
# 25           NaN  595281.0       NaN    0-0  gid_2017_04_02_nyamlb_tbamlb_1
# 26           NaN  595281.0       NaN    1-0  gid_2017_04_02_nyamlb_tbamlb_1
# 27           NaN  595281.0       NaN    2-0  gid_2017_04_02_nyamlb_tbamlb_1
# 28      543543.0       NaN  595281.0    0-0  gid_2017_04_02_nyamlb_tbamlb_1
# 29      543543.0       NaN  595281.0    1-0  gid_2017_04_02_nyamlb_tbamlb_1
# ...          ...       ...       ...    ...                             ...
# 725024       NaN       NaN       NaN    0-0  gid_2017_10_01_cinmlb_chnmlb_1
# 725025       NaN       NaN       NaN    0-1  gid_2017_10_01_cinmlb_chnmlb_1
# 725026       NaN       NaN       NaN    0-2  gid_2017_10_01_cinmlb_chnmlb_1
# 725027       NaN       NaN       NaN    1-2  gid_2017_10_01_cinmlb_chnmlb_1
# 725028       NaN       NaN       NaN    1-2  gid_2017_10_01_cinmlb_chnmlb_1
# 725029       NaN       NaN       NaN    1-2  gid_2017_10_01_cinmlb_chnmlb_1
# 725030       NaN       NaN       NaN    1-2  gid_2017_10_01_cinmlb_chnmlb_1
# 725031       NaN       NaN       NaN    0-0  gid_2017_10_01_cinmlb_chnmlb_1
# 725032       NaN       NaN       NaN    1-0  gid_2017_10_01_cinmlb_chnmlb_1
# 725033       NaN       NaN       NaN    1-1  gid_2017_10_01_cinmlb_chnmlb_1
# 725034       NaN       NaN       NaN    1-2  gid_2017_10_01_cinmlb_chnmlb_1
# 725035       NaN       NaN       NaN    0-0  gid_2017_10_01_cinmlb_chnmlb_1
# 725036       NaN       NaN       NaN    0-0  gid_2017_10_01_cinmlb_chnmlb_1
# 725037       NaN       NaN       NaN    0-1  gid_2017_10_01_cinmlb_chnmlb_1
# 725038       NaN       NaN       NaN    0-2  gid_2017_10_01_cinmlb_chnmlb_1
# 725039       NaN       NaN       NaN    1-2  gid_2017_10_01_cinmlb_chnmlb_1
# 725040       NaN       NaN       NaN    1-2  gid_2017_10_01_cinmlb_chnmlb_1
# 725041       NaN       NaN       NaN    0-0  gid_2017_10_01_cinmlb_chnmlb_1
# 725042       NaN       NaN       NaN    0-1  gid_2017_10_01_cinmlb_chnmlb_1
# 725043       NaN       NaN       NaN    1-1  gid_2017_10_01_cinmlb_chnmlb_1
# 725044  608385.0       NaN       NaN    0-0  gid_2017_10_01_cinmlb_chnmlb_1
# 725045  608385.0       NaN       NaN    1-0  gid_2017_10_01_cinmlb_chnmlb_1
# 725046  608385.0       NaN       NaN    2-0  gid_2017_10_01_cinmlb_chnmlb_1
# 725047  608385.0       NaN       NaN    3-0  gid_2017_10_01_cinmlb_chnmlb_1
# 725048  571740.0  608385.0       NaN    0-0  gid_2017_10_01_cinmlb_chnmlb_1
# 725049       NaN       NaN       NaN    0-0  gid_2017_10_01_cinmlb_chnmlb_1
# 725050       NaN       NaN       NaN    0-0  gid_2017_10_01_cinmlb_chnmlb_1
# 725051       NaN       NaN       NaN    1-0  gid_2017_10_01_cinmlb_chnmlb_1
# 725052       NaN       NaN       NaN    0-0  gid_2017_10_01_cinmlb_chnmlb_1
# 725053       NaN       NaN       NaN    0-0  gid_2017_10_01_cinmlb_chnmlb_1
#
#         code  event_num                             play_guid
# 0          B          3  1a2bff45-cf05-4a65-8b08-0a5e287cd0c2
# 1          C          4  c4813a29-168d-4904-a12e-0a29c5503235
# 2          B          5  8a0f08b0-335f-410e-b751-e1fe2e656cae
# 3          C          6  731141b6-a7df-4e7a-900b-fee0411f7b7b
# 4          F          7  99ffdf74-db8e-4070-a28c-059cb25273d4
# 5          X          8  f614cc42-f0f1-4b55-8954-0dda15329cd9
# 6          X         12  41c737a3-dfa9-4acb-91c7-5097453ff6c7
# 7          C         17  4319c216-c14a-4872-a620-2e7b40990d8d
# 8          B         18  7efbe046-3689-4edf-bfa1-3c358628c6a3
# 9          B         19  d2dc9c60-5209-4eef-8e35-bd8c879b0268
# 10         B         20  4fb6a99a-4db5-4d90-b418-d1b2a7e9929a
# 11         B         21  137b5136-36e8-460d-8485-d1a8d70229a3
# 12         B         25  9a7b7a36-c630-4e5a-a8cc-d4d098b2c415
# 13         C         26  4c50d85a-748d-472d-817c-81e44bd97fd8
# 14         B         27  84021e61-bb88-4d66-ab98-0005ea1ddf8c
# 15         B         28  190354d6-32ff-4964-ac16-f9cf122bcf9e
# 16         X         29  1642fa86-702c-41b1-8014-fa4a4f987e19
# 17         C         36  18ee9f0e-fceb-4e03-a0bd-c19ec16a4142
# 18         D         37  7a1e218d-e40b-44a8-be24-c0f42594196f
# 19         B         41  601e7bb9-122a-463e-b31a-3e712d3c97d4
# 20         B         42  4dcb7a48-ab4b-444e-af3f-74eec811cd44
# 21         F         43  2bb46fda-4782-4fe9-9655-27bb9c5cd320
# 22         D         44  db134a2e-d1e0-4f8f-8a41-78670e18e9f5
# 23         S         49  7d518b09-086a-401e-9eb6-51b1bf18c37b
# 24         E         50  7a1cc011-6f36-440c-9f67-5fab67e5e054
# 25        *B         56  19da55b9-dc7e-435b-a925-7f20a2c0a2b2
# 26         B         57  1f726fb0-c4ff-46cb-b3a5-067e537aa51c
# 27         D         58  1a3e8197-67b7-4b10-b8cc-2e9c39a0f96b
# 28        *B         63  827f79e5-62b4-4318-aa9a-d604f52cea0e
# 29        *B         64  41ef78d2-ff98-4b8c-abc0-37500fe71e02
# ...      ...        ...                                   ...
# 725024     C        492  10df7e9b-9f52-4f51-8807-9276112d7e53
# 725025     F        493  d9a7bd03-8e3e-48ba-82de-6b66103eeafd
# 725026     B        494  21a0bdd5-3c78-408a-a8cb-b605c979b3b6
# 725027     F        495  a2f9644b-3c5c-4817-b0fe-98db133ba6a9
# 725028     F        496  984318cb-0a3f-433e-9293-60f044abcbf8
# 725029     F        497  52d81799-4c56-41a2-97ab-664c564d5de9
# 725030     T        498  06f00dca-4ca6-460e-9259-806967dd5567
# 725031     B        502  04895f32-d3ec-4e3a-b0dd-45a136aabeff
# 725032     C        503  93d3da07-6000-4c88-8134-e7296261a6ed
# 725033     F        504  8b49b0cc-0921-4bae-b910-d8856024d0a0
# 725034     W        505  8ec2afd0-0ad3-4fd9-bb95-3688be29632c
# 725035     X        512  863ec4bd-a53e-4133-a325-b1bbacae57e2
# 725036     C        516  900a5c2c-b0ef-4c4b-831d-c9bd8065a44e
# 725037     F        517  23b4a2bb-1a45-4581-a2bc-5750b25a6997
# 725038     B        518  dcef8b5c-404b-4f46-a0f8-8f4be5f6bd9d
# 725039     F        519  99551a09-ab09-4f37-bf0b-7477c7e0ad45
# 725040     W        520  8387d9d2-c7bf-4a3b-ba5d-f914556417cd
# 725041     C        526  15a5685f-8f84-4e92-8f23-dcf0d6d47f0d
# 725042     B        527  c8dde50d-ea7b-4ba5-8ec5-2628254c6309
# 725043     D        528  2459bdd7-2ab7-4922-ae7a-058a4ed88b10
# 725044     B        532  54644c7c-48b8-4535-be18-e3e4df904b7e
# 725045     B        533  cb78dfbf-9dc6-458a-b53d-7f99e600ccbe
# 725046     B        534  66e6430b-193d-4cad-9aae-3f55807712de
# 725047     B        535  fb9f5e52-db94-43f5-b952-64e9fa57eeb9
# 725048     C        540  2f897ee2-c561-4d7e-834b-58502da36c02
# 725049     X        550  6b1ac80e-4ae4-429b-af1c-ba5f8f82aea9
# 725050     B        554  580aac90-cf25-4079-8605-fff1043197d8
# 725051     E        555  151b4fc5-3c5a-496e-b655-5ec039686c2e
# 725052     X        560  8f458710-9d20-4ba2-b1bf-a564908ec374
# 725053     X        564  cb3a7aca-b8e5-445e-85da-7477537ad739
#
# [725054 rows x 50 columns]

# %% [markdown]
# ## Performing the Query
#
# Since I need data from two tables, I'll have to perform a join. The first column I'll use is 'gameday_link,' but I'll need to join on another column to make sure I'm capturing the correct at bats. The 'num' columns refers to the number of the at bat, and should work as the second parameter to join on.

# %%
df = pd.read_sql_query("SELECT ab.pitcher_name, ab.batter_name, ab.stand, ab.p_throws, p.count, \
                       p.px, p.pz, p.pitch_type, p.on_1b, p.on_2b, p.on_3b, p.num, p.event_num, p.gameday_link \
                       FROM pitch AS p \
                       LEFT OUTER JOIN atbat AS ab \
                       ON ab.gameday_link = p.gameday_link \
                       AND ab.num = p.num;",con)

# %%
#Let's check to see if the query performed as expected

df.head(20)
# Out:
#           pitcher_name      batter_name stand p_throws inning_side count  \
# 0   Christopher Archer    Brett Gardner     L        R         top   0-0
# 1   Christopher Archer    Brett Gardner     L        R         top   1-0
# 2   Christopher Archer    Brett Gardner     L        R         top   1-1
# 3   Christopher Archer    Brett Gardner     L        R         top   2-1
# 4   Christopher Archer    Brett Gardner     L        R         top   2-2
# 5   Christopher Archer    Brett Gardner     L        R         top   2-2
# 6   Christopher Archer     Gary Sanchez     R        R         top   0-0
# 7   Christopher Archer     Gregory Bird     L        R         top   0-0
# 8   Christopher Archer     Gregory Bird     L        R         top   0-1
# 9   Christopher Archer     Gregory Bird     L        R         top   1-1
# 10  Christopher Archer     Gregory Bird     L        R         top   2-1
# 11  Christopher Archer     Gregory Bird     L        R         top   3-1
# 12  Christopher Archer    Matt Holliday     R        R         top   0-0
# 13  Christopher Archer    Matt Holliday     R        R         top   1-0
# 14  Christopher Archer    Matt Holliday     R        R         top   1-1
# 15  Christopher Archer    Matt Holliday     R        R         top   2-1
# 16  Christopher Archer    Matt Holliday     R        R         top   3-1
# 17     Masahiro Tanaka  Corey Dickerson     L        R      bottom   0-0
# 18     Masahiro Tanaka  Corey Dickerson     L        R      bottom   0-1
# 19     Masahiro Tanaka  Kevin Kiermaier     L        R      bottom   0-0
#
#          x       y pitch_type  type_confidence     on_1b  on_2b  on_3b  num  \
# 0    78.78  203.77         FF              2.0       NaN    NaN    NaN  1.0
# 1   111.67  159.76         FF              2.0       NaN    NaN    NaN  1.0
# 2   153.12  160.97         FF              2.0       NaN    NaN    NaN  1.0
# 3   148.28  162.52         FF              2.0       NaN    NaN    NaN  1.0
# 4    87.08  194.67         SL              2.0       NaN    NaN    NaN  1.0
# 5   114.01  188.29         SL              2.0       NaN    NaN    NaN  1.0
# 6   113.85  188.22         FF              2.0       NaN    NaN    NaN  2.0
# 7   138.26  187.76         FF              2.0       NaN    NaN    NaN  3.0
# 8   119.20    0.00         CH              2.0       NaN    NaN    NaN  3.0
# 9    69.52  222.19         CH              2.0       NaN    NaN    NaN  3.0
# 10  153.13  129.46         FF              2.0       NaN    NaN    NaN  3.0
# 11  146.34  131.95         FF              2.0       NaN    NaN    NaN  3.0
# 12   86.27  151.65         FF              2.0  595885.0    NaN    NaN  4.0
# 13  106.29  195.29         SL              2.0  595885.0    NaN    NaN  4.0
# 14  132.71  140.93         FF              2.0  595885.0    NaN    NaN  4.0
# 15   70.23  185.10         FF              2.0  595885.0    NaN    NaN  4.0
# 16   96.30  191.74         SL              2.0  595885.0    NaN    NaN  4.0
# 17  125.24  197.27         SI              2.0       NaN    NaN    NaN  5.0
# 18  121.88  204.11         FS              2.0       NaN    NaN    NaN  5.0
# 19  105.36  201.22         SI              2.0  572816.0    NaN    NaN  6.0
#
#    event_num                    gameday_link
# 0          3  gid_2017_04_02_nyamlb_tbamlb_1
# 1          4  gid_2017_04_02_nyamlb_tbamlb_1
# 2          5  gid_2017_04_02_nyamlb_tbamlb_1
# 3          6  gid_2017_04_02_nyamlb_tbamlb_1
# 4          7  gid_2017_04_02_nyamlb_tbamlb_1
# 5          8  gid_2017_04_02_nyamlb_tbamlb_1
# 6         12  gid_2017_04_02_nyamlb_tbamlb_1
# 7         17  gid_2017_04_02_nyamlb_tbamlb_1
# 8         18  gid_2017_04_02_nyamlb_tbamlb_1
# 9         19  gid_2017_04_02_nyamlb_tbamlb_1
# 10        20  gid_2017_04_02_nyamlb_tbamlb_1
# 11        21  gid_2017_04_02_nyamlb_tbamlb_1
# 12        25  gid_2017_04_02_nyamlb_tbamlb_1
# 13        26  gid_2017_04_02_nyamlb_tbamlb_1
# 14        27  gid_2017_04_02_nyamlb_tbamlb_1
# 15        28  gid_2017_04_02_nyamlb_tbamlb_1
# 16        29  gid_2017_04_02_nyamlb_tbamlb_1
# 17        36  gid_2017_04_02_nyamlb_tbamlb_1
# 18        37  gid_2017_04_02_nyamlb_tbamlb_1
# 19        41  gid_2017_04_02_nyamlb_tbamlb_1

# %% [markdown]
# To confirm that we did not omit any pitch data, we'll check the length of the pitch DataFrame vs the length of our joined DataFrame.

# %%
len(df) == len(pitch)
# Out:
# True

# %% [markdown]
# Alright, looks good. Now let's explore the DataFrame and do any required cleanup, then create some new fields that'll help in the analysis. We can also close the connection to the database since we're done querying.

# %%
#Close db connection
con.close()

# %%
#Check out the dataframe info
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 725054 entries, 0 to 725053
# Data columns (total 16 columns):
# pitcher_name       710468 non-null object
# batter_name        709521 non-null object
# stand              725054 non-null object
# p_throws           725054 non-null object
# inning_side        725054 non-null object
# count              725054 non-null object
# x                  725054 non-null float64
# y                  725054 non-null float64
# pitch_type         719075 non-null object
# type_confidence    719075 non-null float64
# on_1b              220626 non-null float64
# on_2b              135558 non-null float64
# on_3b              68901 non-null float64
# num                725054 non-null float64
# event_num          725054 non-null object
# gameday_link       725054 non-null object
# dtypes: float64(7), object(9)
# memory usage: 88.5+ MB

# %% [markdown]
# We see that there is some data missing in pitcher_name, batter_name, pitch_type, and the columns corresponding to men on bases. For the latter, there is a lot of data missing. Let's take a closer look.

# %%
df['on_1b'].value_counts()
# Out:
# 458015.0    1329
# 592885.0    1037
# 518934.0    1027
# 458731.0    1021
# 592178.0     997
# 429665.0     983
# 592450.0     974
# 543333.0     971
# 519203.0     960
# 408045.0     942
# 502671.0     930
# 542303.0     911
# 572821.0     908
# 429664.0     901
# 446334.0     900
# 453568.0     897
# 457705.0     891
# 643217.0     888
# 594777.0     874
# 514917.0     874
# 514888.0     874
# 443558.0     872
# 553993.0     871
# 430832.0     869
# 542255.0     867
# 455976.0     865
# 541645.0     859
# 457763.0     856
# 545361.0     856
# 519306.0     855
#             ...
# 502042.0       2
# 502046.0       2
# 502706.0       2
# 571666.0       2
# 517414.0       2
# 594992.0       2
# 547179.0       2
# 545363.0       2
# 607352.0       2
# 595453.0       2
# 489232.0       2
# 607259.0       2
# 642336.0       2
# 543089.0       2
# 451705.0       2
# 543208.0       2
# 543408.0       2
# 628711.0       2
# 544928.0       2
# 622663.0       2
# 606930.0       2
# 533167.0       1
# 608650.0       1
# 620982.0       1
# 595373.0       1
# 607074.0       1
# 456124.0       1
# 444468.0       1
# 455374.0       1
# 543213.0       1
# Name: on_1b, dtype: int64

# %% [markdown]
# It looks like these are player IDs. For now, I only really care about whether or not a man is on, not who the specific player is. Let's alter the columns to just indicate if a man is on base or not.

# %%
#Fill NaN's with 0s
df['on_1b'].fillna(0, inplace = True)
df['on_2b'].fillna(0, inplace = True)
df['on_3b'].fillna(0, inplace = True)

#Now convert non-0 values to 1, just to indicate there is a man on. 
df['on_1b'][df['on_1b'] > 0] = 1
df['on_2b'][df['on_2b'] > 0] = 1
df['on_3b'][df['on_3b'] > 0] = 1

#Check info
df.info()
# Out:
# /anaconda/lib/python3.6/site-packages/ipykernel/__main__.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /anaconda/lib/python3.6/site-packages/ipykernel/__main__.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /anaconda/lib/python3.6/site-packages/ipykernel/__main__.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 725054 entries, 0 to 725053
# Data columns (total 16 columns):
# pitcher_name       710468 non-null object
# batter_name        709521 non-null object
# stand              725054 non-null object
# p_throws           725054 non-null object
# inning_side        725054 non-null object
# count              725054 non-null object
# x                  725054 non-null float64
# y                  725054 non-null float64
# pitch_type         719075 non-null object
# type_confidence    719075 non-null float64
# on_1b              725054 non-null float64
# on_2b              725054 non-null float64
# on_3b              725054 non-null float64
# num                725054 non-null float64
# event_num          725054 non-null object
# gameday_link       725054 non-null object
# dtypes: float64(7), object(9)
# memory usage: 88.5+ MB

# %%
#Check to ensure all 0s and 1s
df['on_1b'].value_counts()
# Out:
# 0.0    504428
# 1.0    220626
# Name: on_1b, dtype: int64

# %% [markdown]
# Now to explore the rest of the missing data. For pitcher_name, since I want to look at specific pitchers, I don't mind dropping the rows with no data. Same with pitch_type, if I don't know the pitch type then the instance is no good for me. However, for batter_name, I don't mind not knowing the batter, so I'll fill those with UNKNOWN.

# %%
df['batter_name'].fillna('UNKNOWN', inplace = True)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 725054 entries, 0 to 725053
# Data columns (total 16 columns):
# pitcher_name       710468 non-null object
# batter_name        725054 non-null object
# stand              725054 non-null object
# p_throws           725054 non-null object
# inning_side        725054 non-null object
# count              725054 non-null object
# x                  725054 non-null float64
# y                  725054 non-null float64
# pitch_type         719075 non-null object
# type_confidence    719075 non-null float64
# on_1b              725054 non-null float64
# on_2b              725054 non-null float64
# on_3b              725054 non-null float64
# num                725054 non-null float64
# event_num          725054 non-null object
# gameday_link       725054 non-null object
# dtypes: float64(7), object(9)
# memory usage: 88.5+ MB

# %% [markdown]
# Finally, I'll drop all of the remaining NAs in the data set

# %%
df.dropna(inplace = True)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 704701 entries, 0 to 725053
# Data columns (total 16 columns):
# pitcher_name       704701 non-null object
# batter_name        704701 non-null object
# stand              704701 non-null object
# p_throws           704701 non-null object
# inning_side        704701 non-null object
# count              704701 non-null object
# x                  704701 non-null float64
# y                  704701 non-null float64
# pitch_type         704701 non-null object
# type_confidence    704701 non-null float64
# on_1b              704701 non-null float64
# on_2b              704701 non-null float64
# on_3b              704701 non-null float64
# num                704701 non-null float64
# event_num          704701 non-null object
# gameday_link       704701 non-null object
# dtypes: float64(7), object(9)
# memory usage: 91.4+ MB

# %% [markdown]
# ### Feature Engineering
#
# There are going to be some other columns that I want for my analysis. First, I'd like to split count into balls and strikes so that I can explore what pitchers are throwing in 3-x and x-2 counts. I'd also like to capture the previous pitch thrown in the at bat.

# %%
#Create separate balls and strikes columns

df['b'] = df['count'].apply(lambda x: x.split('-')[0])
df['s'] = df['count'].apply(lambda x: x.split('-')[1])
df.head()
# Out:
#          pitcher_name    batter_name stand p_throws inning_side count       x  \
# 0  Christopher Archer  Brett Gardner     L        R         top   0-0   78.78
# 1  Christopher Archer  Brett Gardner     L        R         top   1-0  111.67
# 2  Christopher Archer  Brett Gardner     L        R         top   1-1  153.12
# 3  Christopher Archer  Brett Gardner     L        R         top   2-1  148.28
# 4  Christopher Archer  Brett Gardner     L        R         top   2-2   87.08
#
#         y pitch_type  type_confidence  on_1b  on_2b  on_3b  num event_num  \
# 0  203.77         FF              2.0    0.0    0.0    0.0  1.0         3
# 1  159.76         FF              2.0    0.0    0.0    0.0  1.0         4
# 2  160.97         FF              2.0    0.0    0.0    0.0  1.0         5
# 3  162.52         FF              2.0    0.0    0.0    0.0  1.0         6
# 4  194.67         SL              2.0    0.0    0.0    0.0  1.0         7
#
#                      gameday_link  b  s
# 0  gid_2017_04_02_nyamlb_tbamlb_1  0  0
# 1  gid_2017_04_02_nyamlb_tbamlb_1  1  0
# 2  gid_2017_04_02_nyamlb_tbamlb_1  1  1
# 3  gid_2017_04_02_nyamlb_tbamlb_1  2  1
# 4  gid_2017_04_02_nyamlb_tbamlb_1  2  2

# %%
#Write to CSV for future use
df.to_csv('2017_pitchfx.csv', index = False)
